# %%
pip install pandas
pip install numpy
# Out:
#   Cell In[1], line 1
#     pip install pandas
#         ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_excel('/content/AFE7518-L2-AgeVs.Salary.xlsx')
df
# Out:
#    Age  Salary
# 0   25  135000
# 1   55  260000
# 2   27  105000
# 3   35  220000
# 4   60  240000
# 5   65  265000
# 6   45  270000
# 7   40  300000
# 8   50  265000
# 9   30  105000

# %%
df.plot.scatter('Age','Salary')

# %%
x1 = df['Age']
y = df['Salary']
print(x1)
print(y)
# Out:
# 0    25
# 1    55
# 2    27
# 3    35
# 4    60
# 5    65
# 6    45
# 7    40
# 8    50
# 9    30
# Name: Age, dtype: int64
# 0    135000
# 1    260000
# 2    105000
# 3    220000
# 4    240000
# 5    265000
# 6    270000
# 7    300000
# 8    265000
# 9    105000
# Name: Salary, dtype: int64

# %%
pip install statsmodels
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import statsmodels.api as sm

# %%
X = sm.add_constant(x1)
#print(X)
reg = sm.OLS(y,X).fit()
print(reg.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 Salary   R-squared:                       0.541
# Model:                            OLS   Adj. R-squared:                  0.484
# Method:                 Least Squares   F-statistic:                     9.432
# Date:                Thu, 09 Feb 2023   Prob (F-statistic):             0.0153
# Time:                        14:30:22   Log-Likelihood:                -121.81
# No. Observations:                  10   AIC:                             247.6
# Df Residuals:                       8   BIC:                             248.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       5.116e+04   5.64e+04      0.908      0.391   -7.88e+04    1.81e+05
# ...
